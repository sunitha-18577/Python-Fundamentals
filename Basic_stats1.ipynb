# %% [markdown]
# <a href="https://colab.research.google.com/github/sunitha-18577/Python-Fundamentals/blob/main/Basic_stats1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
try:
    pass # Add a pass statement or other code block
except:
    pass # Add exception handling

# %%
df=pd.read_csv('/content/sales discounts.csv')

# %%
numerical_cols=df.select_dtypes(include=['number'])

# %%
from pathlib import PureWindowsPath
if not numerical_cols.empty:
  print("Basic Statistics for Numerical Columns:")
  for col in numerical_cols.columns:
    print(f"\nColumn: {col}")
    print(f"Mean: {df[col].mean()}")
    print(f"Median: {df[col].median()}")
# Out:
# Basic Statistics for Numerical Columns:
#
# Column: Volume
# Mean: 5.066666666666666
# Median: 4.0
#
# Column: Avg Price
# Mean: 10453.433333333332
# Median: 1450.0
#
# Column: Total Sales Value
# Mean: 33812.83555555555
# Median: 5700.0
#
# Column: Discount Rate (%)
# Mean: 15.15524189526222
# Median: 16.57776565
#
# Column: Discount Amount
# Mean: 3346.4994243526
# Median: 988.93373325
#
# Column: Net Sales Value
# Mean: 30466.33613109089
# Median: 4677.7880595

# %%
import matplotlib.pyplot as plt

# %%
if not numerical_cols.empty:
  print("Basic Statistics for Numerical Columns:")
  for col in numerical_cols.columns:
    plt.figure(figsize=( 8,6))
    plt.hist(df[col],bins=20,color='skyblue',edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Basic Statistics for Numerical Columns:

# %%
skewness=df[col].skew()
print(f"Skewness of {col}: {skewness:.2f}")
if skewness > 0.5:
  print(f"{col} is positively skewed.")
elif skewness < -0.5:
  print(f"{col} is negatively skewed.")
else:
  print(f"{col} is approximately symmetric.")
# Out:
# Skewness of Net Sales Value: 1.54
# Net Sales Value is positively skewed.

# %%
mean=df[col].mean()
std_dev=df[col].std()
outliers=df[(df[col] < mean - 3 * std_dev) | (df[col] > mean + 3 * std_dev)]
print(f"Mean of {col}: {mean:.2f}")
print(f"Standard Deviation of {col}: {std_dev:.2f}")
# Out:
# Mean of Net Sales Value: 30466.34
# Standard Deviation of Net Sales Value: 46358.66

# %%
print("\nBoxplots for numerical columns:")
for col in numerical_cols.columns:
  plt.figure(figsize=(8, 6))
  plt.boxplot(df[col],vert=False)
  plt.title(f'Boxplot of {col}')
  plt.xlabel(col)

  plt.show()
# Out:
# Boxplots for numerical columns:

# %%
Q1=df[col].quantile(0.25)
Q3=df[col].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# %%
if not outliers.empty:
  print(f"Outliers in {col}:")
  print(outliers)
else:
  print(f"No outliers found in {col}.")
# Out:
# Outliers in Net Sales Value:
#           Date       Day  SKU City  Volume       BU    Brand Model  Avg Price  \
# 66  03-04-2021  Saturday  M07    C       4  Mobiles  Sumsang  S-20      49100
#
#     Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# 66             196400            8.60108      16892.52095       179507.479

# %%
print("\nBar chart for categorical columns:")
import seaborn as sns
categorical_cols=df.select_dtypes(include=['object']).columns
for col in categorical_cols:
  plt.figure(figsize=(8,6))
  sns.countplot(data=df,x=col)
  plt.title(f'Distribution of {col}')
  plt.xlabel(col)
  plt.ylabel('count')
  plt.xticks(rotation=45)
  plt.show()
  print(f"Analysis of {col} distribution:")
  print(df[col].value_counts())
# Out:
# Bar chart for categorical columns:
# Analysis of Date distribution:
# Date
# 01-04-2021    30
# 02-04-2021    30
# 03-04-2021    30
# 04-04-2021    30
# 05-04-2021    30
# 06-04-2021    30
# 07-04-2021    30
# 08-04-2021    30
# 09-04-2021    30
# 10-04-2021    30
# 11-04-2021    30
# 12-04-2021    30
# 13-04-2021    30
# 14-04-2021    30
# 15-04-2021    30
# Name: count, dtype: int64
# Analysis of Day distribution:
# Day
# Thursday     90
# Friday       60
# Saturday     60
# Sunday       60
# Monday       60
# Tuesday      60
# Wednesday    60
# Name: count, dtype: int64
# Analysis of SKU distribution:
# SKU
# M01    15
# M02    15
# M03    15
# M04    15
# M05    15
# M06    15
# M07    15
# M08    15
# M09    15
# M10    15
# F01    15
# F02    15
# F03    15
# F04    15
# F05    15
# F06    15
# F07    15
# F08    15
# F09    15
# F10    15
# L01    15
# L02    15
# L03    15
# L04    15
# L05    15
# L06    15
# L07    15
# L08    15
# L09    15
# L10    15
# ...
